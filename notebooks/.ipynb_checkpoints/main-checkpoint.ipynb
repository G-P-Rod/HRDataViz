# %%
import os
import pandas as pd
import numpy as np

# %%
#Get current and parent directory directory
current_path = os.getcwd()
parent_directory = os.path.dirname(current_path)

#Create a path to the source folder where the raw data is located
source_path = os.path.join(parent_directory, 'data', 'raw', 'data_per_day.xlsx')

#Create a path to the destination file
destination_path = os.path.join(parent_directory, 'data', 'processed')

# Get all .xlsx files in the source directory
#file = glob.glob(os.path.join(source_path, "*.xlsx"))

#Read the .xlsx file
df = pd.read_excel(source_path, index_col=None)

# %%
display(df)
# Out:
#      Numer osobowy                Główny Obszar Obszar kadrowy - tekst  \
# 0      Person 3650  Działalność Administracyjna               Kanclerz
# 1      Person 3649  Działalność Administracyjna               Kanclerz
# 2      Person 3671  Działalność Administracyjna               Kanclerz
# 3      Person 3685  Działalność Administracyjna               Kanclerz
# 4      Person 4461  Działalność Administracyjna               Kanclerz
# ...            ...                          ...                    ...
# 4376   Person 4992  Działalność Administracyjna   Zastępca Kanclerza B
# 4377   Person 5033  Działalność Administracyjna   Zastępca Kanclerza B
# 4378   Person 5011  Działalność Administracyjna   Zastępca Kanclerza B
# 4379   Person 5030  Działalność Administracyjna   Zastępca Kanclerza B
# 4380   Person 4936  Działalność Administracyjna   Zastępca Kanclerza B
#
#      Podobszar kadrowy - tekst  Unnamed: 4  Unnamed: 5  Podgrupa pracowników  \
# ...

# %%
df_by_glowny_obszar = df.groupby(['Główny Obszar', 'Obszar kadrowy - tekst', 'Podobszar kadrowy - tekst']).count()
display(df_by_glowny_obszar)
# Out:
#                                                                               Numer osobowy  \
# Główny Obszar               Obszar kadrowy - tekst Podobszar kadrowy - tekst
# Działalność Administracyjna Kanclerz               ABM                                   17
#                                                    BIURO KANCLERZA                       10
#                                                    BIURO OBSŁ PRAW                       15
#                                                    Biuro Spraw Oso                       25
#                                                    CIPW                                  67
# ...                                                                                     ...
# Wydziały                    W.SiMR                 I.PBM                                 49
#                                                    I.PiMR                                62
# ...

# %%
df_pivot = df.pivot_table(values='Etat', index=['Główny Obszar', 'Obszar kadrowy - tekst'], aggfunc=['mean', 'min', 'max'])
print(df_pivot)
# Out:
#                                                         mean   min  max
#                                                         Etat  Etat Etat
# Główny Obszar               Obszar kadrowy - tekst
# Działalność Administracyjna Kanclerz                0.982529  0.25  1.0
#                             Kwestor                 0.991781  0.40  1.0
#                             Rektor                  0.948101  0.50  1.0
#                             Zastępca Kanclerza A    0.896324  0.25  1.0
#                             Zastępca Kanclerza B    0.987234  0.50  1.0
# Wydziały                    W.AiNS                  0.924342  0.50  1.0
#                             W.Arch                  0.804413  0.25  1.0
#                             W.Chem                  0.927642  0.10  1.0
#                             W.EiTI                  0.894547  0.10  1.0
#                             W.El-ny                 0.918776  0.25  1.0
# ...
