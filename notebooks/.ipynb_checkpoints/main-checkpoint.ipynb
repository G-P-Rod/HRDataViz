# %%
import os
import pandas as pd
import numpy as np

from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import letter
from reportlab.lib import utils
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont

# %%
#Get current and parent directory directory
current_path = os.getcwd()
parent_directory = os.path.dirname(current_path)

#Path to the source folder where the raw data is located
source_path = os.path.join(parent_directory, 'data', 'raw', 'data_per_day.xlsx')

#Path to the image
image_path = os.path.join(parent_directory, 'graphics', 'bow.png')

#Path to the destination file
destination_path = os.path.join(parent_directory, 'data', 'processed', 'output.pdf')

#Read the .xlsx file
df = pd.read_excel(source_path, index_col=None)

# %%
#Main distinction is saved in the system as 'NA' and 'NNA'. 'NA' is read as a empty value.
#We need fill 'empty' value as a teachers, and change 'NNA' as a not teachers.
df['Grupa pracowników'] = df['Grupa pracowników'].fillna('Nauczyciel')
df['Grupa pracowników'] = df['Grupa pracowników'].replace('NNA', 'Nienauczyciel')

# %%
display(df)
# Out:
#      Numer osobowy Obszar kadrowy       Podobszar kadrowy  \
# 0      Person 1310      Wydział 1               Wydział 1
# 1      Person 1312      Wydział 1               Wydział 1
# 2      Person 1314      Wydział 1               Wydział 1
# 3      Person 1315      Wydział 1               Wydział 1
# 4      Person 1318      Wydział 1               Wydział 1
# ...            ...            ...                     ...
# 1402   Person 1031      Wydział 4  Wydział 4 - instytut 2
# 1403   Person 1042      Wydział 4  Wydział 4 - instytut 2
# 1404   Person 1058      Wydział 4  Wydział 4 - instytut 2
# 1405   Person 1159      Wydział 5  Wydział 5 - instytut 1
# 1406   Person 1205      Wydział 5  Wydział 5 - instytut 1
#
#       Podgrupa pracowników        Stanowisko  Etat       Płeć  \
# 0              Dydaktyczni           adiunkt   1.0  Mężczyzna
# 1     Badawczo-dydaktyczni           adiunkt   1.0  Mężczyzna
# 2     Badawczo-dydaktyczni           adiunkt   1.0  Mężczyzna
# 3     Badawczo-dydaktyczni           adiunkt   1.0  Mężczyzna
# 4     Badawczo-dydaktyczni           adiunkt   1.0    Kobieta
# ...                    ...               ...   ...        ...
# 1402           Dydaktyczni  starszy asystent   1.0    Kobieta
# 1403           Dydaktyczni  starszy asystent   1.0  Mężczyzna
# 1404           Dydaktyczni  starszy asystent   1.0  Mężczyzna
# 1405           Dydaktyczni  starszy asystent   1.0  Mężczyzna
# 1406           Dydaktyczni  starszy asystent   1.0  Mężczyzna
#
#                 Tytuł Grupa pracowników  Wiek  Wynagrodzenie
# 0              doktor        Nauczyciel    41           7839
# 1              doktor        Nauczyciel    38           7415
# 2     dr habilitowany        Nauczyciel    56           6389
# 3              doktor        Nauczyciel    55           6987
# 4              doktor        Nauczyciel    36           6064
# ...               ...               ...   ...            ...
# 1402     mgr inżynier        Nauczyciel    61           6450
# 1403     mgr inżynier        Nauczyciel    38           5029
# 1404     mgr inżynier        Nauczyciel    40           6057
# 1405     mgr inżynier        Nauczyciel    50           5369
# 1406     mgr inżynier        Nauczyciel    61           4975
#
# [1407 rows x 11 columns]

# %%
df_by_glowny_obszar = df.groupby(['Obszar kadrowy', 'Podobszar kadrowy']).count()
display(df_by_glowny_obszar)
# Out:
#                                        Numer osobowy  Podgrupa pracowników  \
# Obszar kadrowy Podobszar kadrowy
# Wydział 1      Wydział 1                         185                   185
# Wydział 2      Wydział 2                         179                   179
# Wydział 3      Wydział 3                         246                   246
# Wydział 4      Wydział 4 - instytut 1            230                   230
#                Wydział 4 - instytut 2            242                   242
#                Wydział 4 - instytut 3             80                    80
# Wydział 5      Wydział 5 - instytut 1            216                   216
#                Wydział 5 - instytut 2             29                    29
#
#                                        Stanowisko  Etat  Płeć  Tytuł  \
# Obszar kadrowy Podobszar kadrowy
# Wydział 1      Wydział 1                      185   185   185    167
# Wydział 2      Wydział 2                      179   179   179    159
# Wydział 3      Wydział 3                      246   246   246    208
# Wydział 4      Wydział 4 - instytut 1         230   230   230    220
#                Wydział 4 - instytut 2         242   242   242    230
#                Wydział 4 - instytut 3          80    80    80     32
# Wydział 5      Wydział 5 - instytut 1         216   216   216    204
#                Wydział 5 - instytut 2          29    29    29     11
#
#                                        Grupa pracowników  Wiek  Wynagrodzenie
# Obszar kadrowy Podobszar kadrowy
# Wydział 1      Wydział 1                             185   185            185
# Wydział 2      Wydział 2                             179   179            179
# Wydział 3      Wydział 3                             246   246            246
# Wydział 4      Wydział 4 - instytut 1                230   230            230
#                Wydział 4 - instytut 2                242   242            242
#                Wydział 4 - instytut 3                 80    80             80
# Wydział 5      Wydział 5 - instytut 1                216   216            216
#                Wydział 5 - instytut 2                 29    29             29

# %%
for i in df['Obszar kadrowy'].unique():
    df_pivot = df[df['Obszar kadrowy'] == i].pivot_table(values='Etat', index=['Obszar kadrowy'], columns='Grupa pracowników', 
               aggfunc=['count', 'sum']).style.background_gradient(cmap='Greens')
    #df_pivot = df_pivot.style.set_table_styles([{'selector': 'thead',
    #                                             'props': [('border', '1px solid black')]}])
    
    df_describe = df.describe().drop(['count', 'std']).style.background_gradient(cmap='Greens')
    display(df_pivot, df_describe)
# Out:
# <style type="text/css">
# #T_c3b25_row0_col0, #T_c3b25_row0_col1, #T_c3b25_row0_col2, #T_c3b25_row0_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_c3b25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3b25_level0_col0" class="col_heading level0 col0" colspan="2">count</th>
#       <th id="T_c3b25_level0_col2" class="col_heading level0 col2" colspan="2">sum</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Grupa pracowników</th>
#       <th id="T_c3b25_level1_col0" class="col_heading level1 col0" >Nauczyciel</th>
#       <th id="T_c3b25_level1_col1" class="col_heading level1 col1" >Nienauczyciel</th>
#       <th id="T_c3b25_level1_col2" class="col_heading level1 col2" >Nauczyciel</th>
#       <th id="T_c3b25_level1_col3" class="col_heading level1 col3" >Nienauczyciel</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Obszar kadrowy</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3b25_level0_row0" class="row_heading level0 row0" >Wydział 1</th>
#       <td id="T_c3b25_row0_col0" class="data row0 col0" >115</td>
#       <td id="T_c3b25_row0_col1" class="data row0 col1" >70</td>
#       <td id="T_c3b25_row0_col2" class="data row0 col2" >107.050000</td>
#       <td id="T_c3b25_row0_col3" class="data row0 col3" >58.050000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_eedfb_row0_col0 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_eedfb_row0_col1 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_eedfb_row0_col2 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_eedfb_row1_col0, #T_eedfb_row1_col1, #T_eedfb_row1_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_eedfb_row2_col0, #T_eedfb_row3_col0, #T_eedfb_row4_col0, #T_eedfb_row5_col0, #T_eedfb_row5_col1, #T_eedfb_row5_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_eedfb_row2_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_eedfb_row2_col2 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_eedfb_row3_col1 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_eedfb_row3_col2 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_eedfb_row4_col1 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_eedfb_row4_col2 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# </style>
# <table id="T_eedfb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eedfb_level0_col0" class="col_heading level0 col0" >Etat</th>
#       <th id="T_eedfb_level0_col1" class="col_heading level0 col1" >Wiek</th>
#       <th id="T_eedfb_level0_col2" class="col_heading level0 col2" >Wynagrodzenie</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eedfb_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_eedfb_row0_col0" class="data row0 col0" >0.892807</td>
#       <td id="T_eedfb_row0_col1" class="data row0 col1" >46.191898</td>
#       <td id="T_eedfb_row0_col2" class="data row0 col2" >7035.378820</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row1" class="row_heading level0 row1" >min</th>
#       <td id="T_eedfb_row1_col0" class="data row1 col0" >0.100000</td>
#       <td id="T_eedfb_row1_col1" class="data row1 col1" >30.000000</td>
#       <td id="T_eedfb_row1_col2" class="data row1 col2" >4002.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row2" class="row_heading level0 row2" >25%</th>
#       <td id="T_eedfb_row2_col0" class="data row2 col0" >1.000000</td>
#       <td id="T_eedfb_row2_col1" class="data row2 col1" >38.000000</td>
#       <td id="T_eedfb_row2_col2" class="data row2 col2" >5631.500000</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row3" class="row_heading level0 row3" >50%</th>
#       <td id="T_eedfb_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_eedfb_row3_col1" class="data row3 col1" >46.000000</td>
#       <td id="T_eedfb_row3_col2" class="data row3 col2" >6612.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row4" class="row_heading level0 row4" >75%</th>
#       <td id="T_eedfb_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_eedfb_row4_col1" class="data row4 col1" >54.000000</td>
#       <td id="T_eedfb_row4_col2" class="data row4 col2" >7583.500000</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row5" class="row_heading level0 row5" >max</th>
#       <td id="T_eedfb_row5_col0" class="data row5 col0" >1.000000</td>
#       <td id="T_eedfb_row5_col1" class="data row5 col1" >62.000000</td>
#       <td id="T_eedfb_row5_col2" class="data row5 col2" >14850.000000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_799a6_row0_col0, #T_799a6_row0_col1, #T_799a6_row0_col2, #T_799a6_row0_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_799a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_799a6_level0_col0" class="col_heading level0 col0" colspan="2">count</th>
#       <th id="T_799a6_level0_col2" class="col_heading level0 col2" colspan="2">sum</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Grupa pracowników</th>
#       <th id="T_799a6_level1_col0" class="col_heading level1 col0" >Nauczyciel</th>
#       <th id="T_799a6_level1_col1" class="col_heading level1 col1" >Nienauczyciel</th>
#       <th id="T_799a6_level1_col2" class="col_heading level1 col2" >Nauczyciel</th>
#       <th id="T_799a6_level1_col3" class="col_heading level1 col3" >Nienauczyciel</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Obszar kadrowy</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_799a6_level0_row0" class="row_heading level0 row0" >Wydział 2</th>
#       <td id="T_799a6_row0_col0" class="data row0 col0" >138</td>
#       <td id="T_799a6_row0_col1" class="data row0 col1" >41</td>
#       <td id="T_799a6_row0_col2" class="data row0 col2" >104.490000</td>
#       <td id="T_799a6_row0_col3" class="data row0 col3" >39.500000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_5a6e9_row0_col0 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_5a6e9_row0_col1 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_5a6e9_row0_col2 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_5a6e9_row1_col0, #T_5a6e9_row1_col1, #T_5a6e9_row1_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_5a6e9_row2_col0, #T_5a6e9_row3_col0, #T_5a6e9_row4_col0, #T_5a6e9_row5_col0, #T_5a6e9_row5_col1, #T_5a6e9_row5_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_5a6e9_row2_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_5a6e9_row2_col2 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_5a6e9_row3_col1 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_5a6e9_row3_col2 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_5a6e9_row4_col1 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_5a6e9_row4_col2 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# </style>
# <table id="T_5a6e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a6e9_level0_col0" class="col_heading level0 col0" >Etat</th>
#       <th id="T_5a6e9_level0_col1" class="col_heading level0 col1" >Wiek</th>
#       <th id="T_5a6e9_level0_col2" class="col_heading level0 col2" >Wynagrodzenie</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a6e9_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_5a6e9_row0_col0" class="data row0 col0" >0.892807</td>
#       <td id="T_5a6e9_row0_col1" class="data row0 col1" >46.191898</td>
#       <td id="T_5a6e9_row0_col2" class="data row0 col2" >7035.378820</td>
#     </tr>
#     <tr>
#       <th id="T_5a6e9_level0_row1" class="row_heading level0 row1" >min</th>
#       <td id="T_5a6e9_row1_col0" class="data row1 col0" >0.100000</td>
#       <td id="T_5a6e9_row1_col1" class="data row1 col1" >30.000000</td>
#       <td id="T_5a6e9_row1_col2" class="data row1 col2" >4002.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5a6e9_level0_row2" class="row_heading level0 row2" >25%</th>
#       <td id="T_5a6e9_row2_col0" class="data row2 col0" >1.000000</td>
#       <td id="T_5a6e9_row2_col1" class="data row2 col1" >38.000000</td>
#       <td id="T_5a6e9_row2_col2" class="data row2 col2" >5631.500000</td>
#     </tr>
#     <tr>
#       <th id="T_5a6e9_level0_row3" class="row_heading level0 row3" >50%</th>
#       <td id="T_5a6e9_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_5a6e9_row3_col1" class="data row3 col1" >46.000000</td>
#       <td id="T_5a6e9_row3_col2" class="data row3 col2" >6612.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5a6e9_level0_row4" class="row_heading level0 row4" >75%</th>
#       <td id="T_5a6e9_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_5a6e9_row4_col1" class="data row4 col1" >54.000000</td>
#       <td id="T_5a6e9_row4_col2" class="data row4 col2" >7583.500000</td>
#     </tr>
#     <tr>
#       <th id="T_5a6e9_level0_row5" class="row_heading level0 row5" >max</th>
#       <td id="T_5a6e9_row5_col0" class="data row5 col0" >1.000000</td>
#       <td id="T_5a6e9_row5_col1" class="data row5 col1" >62.000000</td>
#       <td id="T_5a6e9_row5_col2" class="data row5 col2" >14850.000000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a0363_row0_col0, #T_a0363_row0_col1, #T_a0363_row0_col2, #T_a0363_row0_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_a0363">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0363_level0_col0" class="col_heading level0 col0" colspan="2">count</th>
#       <th id="T_a0363_level0_col2" class="col_heading level0 col2" colspan="2">sum</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Grupa pracowników</th>
#       <th id="T_a0363_level1_col0" class="col_heading level1 col0" >Nauczyciel</th>
#       <th id="T_a0363_level1_col1" class="col_heading level1 col1" >Nienauczyciel</th>
#       <th id="T_a0363_level1_col2" class="col_heading level1 col2" >Nauczyciel</th>
#       <th id="T_a0363_level1_col3" class="col_heading level1 col3" >Nienauczyciel</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Obszar kadrowy</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0363_level0_row0" class="row_heading level0 row0" >Wydział 3</th>
#       <td id="T_a0363_row0_col0" class="data row0 col0" >151</td>
#       <td id="T_a0363_row0_col1" class="data row0 col1" >95</td>
#       <td id="T_a0363_row0_col2" class="data row0 col2" >142.950000</td>
#       <td id="T_a0363_row0_col3" class="data row0 col3" >85.250000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e3ef9_row0_col0 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_e3ef9_row0_col1 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_e3ef9_row0_col2 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_e3ef9_row1_col0, #T_e3ef9_row1_col1, #T_e3ef9_row1_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_e3ef9_row2_col0, #T_e3ef9_row3_col0, #T_e3ef9_row4_col0, #T_e3ef9_row5_col0, #T_e3ef9_row5_col1, #T_e3ef9_row5_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_e3ef9_row2_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_e3ef9_row2_col2 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_e3ef9_row3_col1 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_e3ef9_row3_col2 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_e3ef9_row4_col1 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_e3ef9_row4_col2 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# </style>
# <table id="T_e3ef9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3ef9_level0_col0" class="col_heading level0 col0" >Etat</th>
#       <th id="T_e3ef9_level0_col1" class="col_heading level0 col1" >Wiek</th>
#       <th id="T_e3ef9_level0_col2" class="col_heading level0 col2" >Wynagrodzenie</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3ef9_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_e3ef9_row0_col0" class="data row0 col0" >0.892807</td>
#       <td id="T_e3ef9_row0_col1" class="data row0 col1" >46.191898</td>
#       <td id="T_e3ef9_row0_col2" class="data row0 col2" >7035.378820</td>
#     </tr>
#     <tr>
#       <th id="T_e3ef9_level0_row1" class="row_heading level0 row1" >min</th>
#       <td id="T_e3ef9_row1_col0" class="data row1 col0" >0.100000</td>
#       <td id="T_e3ef9_row1_col1" class="data row1 col1" >30.000000</td>
#       <td id="T_e3ef9_row1_col2" class="data row1 col2" >4002.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e3ef9_level0_row2" class="row_heading level0 row2" >25%</th>
#       <td id="T_e3ef9_row2_col0" class="data row2 col0" >1.000000</td>
#       <td id="T_e3ef9_row2_col1" class="data row2 col1" >38.000000</td>
#       <td id="T_e3ef9_row2_col2" class="data row2 col2" >5631.500000</td>
#     </tr>
#     <tr>
#       <th id="T_e3ef9_level0_row3" class="row_heading level0 row3" >50%</th>
#       <td id="T_e3ef9_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_e3ef9_row3_col1" class="data row3 col1" >46.000000</td>
#       <td id="T_e3ef9_row3_col2" class="data row3 col2" >6612.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e3ef9_level0_row4" class="row_heading level0 row4" >75%</th>
#       <td id="T_e3ef9_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_e3ef9_row4_col1" class="data row4 col1" >54.000000</td>
#       <td id="T_e3ef9_row4_col2" class="data row4 col2" >7583.500000</td>
#     </tr>
#     <tr>
#       <th id="T_e3ef9_level0_row5" class="row_heading level0 row5" >max</th>
#       <td id="T_e3ef9_row5_col0" class="data row5 col0" >1.000000</td>
#       <td id="T_e3ef9_row5_col1" class="data row5 col1" >62.000000</td>
#       <td id="T_e3ef9_row5_col2" class="data row5 col2" >14850.000000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_104d8_row0_col0, #T_104d8_row0_col1, #T_104d8_row0_col2, #T_104d8_row0_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_104d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_104d8_level0_col0" class="col_heading level0 col0" colspan="2">count</th>
#       <th id="T_104d8_level0_col2" class="col_heading level0 col2" colspan="2">sum</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Grupa pracowników</th>
#       <th id="T_104d8_level1_col0" class="col_heading level1 col0" >Nauczyciel</th>
#       <th id="T_104d8_level1_col1" class="col_heading level1 col1" >Nienauczyciel</th>
#       <th id="T_104d8_level1_col2" class="col_heading level1 col2" >Nauczyciel</th>
#       <th id="T_104d8_level1_col3" class="col_heading level1 col3" >Nienauczyciel</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Obszar kadrowy</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_104d8_level0_row0" class="row_heading level0 row0" >Wydział 4</th>
#       <td id="T_104d8_row0_col0" class="data row0 col0" >363</td>
#       <td id="T_104d8_row0_col1" class="data row0 col1" >189</td>
#       <td id="T_104d8_row0_col2" class="data row0 col2" >324.290000</td>
#       <td id="T_104d8_row0_col3" class="data row0 col3" >169.500000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2b187_row0_col0 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_2b187_row0_col1 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_2b187_row0_col2 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_2b187_row1_col0, #T_2b187_row1_col1, #T_2b187_row1_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_2b187_row2_col0, #T_2b187_row3_col0, #T_2b187_row4_col0, #T_2b187_row5_col0, #T_2b187_row5_col1, #T_2b187_row5_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2b187_row2_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_2b187_row2_col2 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_2b187_row3_col1 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_2b187_row3_col2 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_2b187_row4_col1 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_2b187_row4_col2 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# </style>
# <table id="T_2b187">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b187_level0_col0" class="col_heading level0 col0" >Etat</th>
#       <th id="T_2b187_level0_col1" class="col_heading level0 col1" >Wiek</th>
#       <th id="T_2b187_level0_col2" class="col_heading level0 col2" >Wynagrodzenie</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b187_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_2b187_row0_col0" class="data row0 col0" >0.892807</td>
#       <td id="T_2b187_row0_col1" class="data row0 col1" >46.191898</td>
#       <td id="T_2b187_row0_col2" class="data row0 col2" >7035.378820</td>
#     </tr>
#     <tr>
#       <th id="T_2b187_level0_row1" class="row_heading level0 row1" >min</th>
#       <td id="T_2b187_row1_col0" class="data row1 col0" >0.100000</td>
#       <td id="T_2b187_row1_col1" class="data row1 col1" >30.000000</td>
#       <td id="T_2b187_row1_col2" class="data row1 col2" >4002.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2b187_level0_row2" class="row_heading level0 row2" >25%</th>
#       <td id="T_2b187_row2_col0" class="data row2 col0" >1.000000</td>
#       <td id="T_2b187_row2_col1" class="data row2 col1" >38.000000</td>
#       <td id="T_2b187_row2_col2" class="data row2 col2" >5631.500000</td>
#     </tr>
#     <tr>
#       <th id="T_2b187_level0_row3" class="row_heading level0 row3" >50%</th>
#       <td id="T_2b187_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_2b187_row3_col1" class="data row3 col1" >46.000000</td>
#       <td id="T_2b187_row3_col2" class="data row3 col2" >6612.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2b187_level0_row4" class="row_heading level0 row4" >75%</th>
#       <td id="T_2b187_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_2b187_row4_col1" class="data row4 col1" >54.000000</td>
#       <td id="T_2b187_row4_col2" class="data row4 col2" >7583.500000</td>
#     </tr>
#     <tr>
#       <th id="T_2b187_level0_row5" class="row_heading level0 row5" >max</th>
#       <td id="T_2b187_row5_col0" class="data row5 col0" >1.000000</td>
#       <td id="T_2b187_row5_col1" class="data row5 col1" >62.000000</td>
#       <td id="T_2b187_row5_col2" class="data row5 col2" >14850.000000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0c317_row0_col0, #T_0c317_row0_col1, #T_0c317_row0_col2, #T_0c317_row0_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_0c317">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c317_level0_col0" class="col_heading level0 col0" colspan="2">count</th>
#       <th id="T_0c317_level0_col2" class="col_heading level0 col2" colspan="2">sum</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Grupa pracowników</th>
#       <th id="T_0c317_level1_col0" class="col_heading level1 col0" >Nauczyciel</th>
#       <th id="T_0c317_level1_col1" class="col_heading level1 col1" >Nienauczyciel</th>
#       <th id="T_0c317_level1_col2" class="col_heading level1 col2" >Nauczyciel</th>
#       <th id="T_0c317_level1_col3" class="col_heading level1 col3" >Nienauczyciel</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Obszar kadrowy</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c317_level0_row0" class="row_heading level0 row0" >Wydział 5</th>
#       <td id="T_0c317_row0_col0" class="data row0 col0" >175</td>
#       <td id="T_0c317_row0_col1" class="data row0 col1" >70</td>
#       <td id="T_0c317_row0_col2" class="data row0 col2" >160.700000</td>
#       <td id="T_0c317_row0_col3" class="data row0 col3" >64.400000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c3772_row0_col0 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_c3772_row0_col1 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_c3772_row0_col2 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_c3772_row1_col0, #T_c3772_row1_col1, #T_c3772_row1_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_c3772_row2_col0, #T_c3772_row3_col0, #T_c3772_row4_col0, #T_c3772_row5_col0, #T_c3772_row5_col1, #T_c3772_row5_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_c3772_row2_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_c3772_row2_col2 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_c3772_row3_col1 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_c3772_row3_col2 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_c3772_row4_col1 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_c3772_row4_col2 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# </style>
# <table id="T_c3772">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3772_level0_col0" class="col_heading level0 col0" >Etat</th>
#       <th id="T_c3772_level0_col1" class="col_heading level0 col1" >Wiek</th>
#       <th id="T_c3772_level0_col2" class="col_heading level0 col2" >Wynagrodzenie</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3772_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_c3772_row0_col0" class="data row0 col0" >0.892807</td>
#       <td id="T_c3772_row0_col1" class="data row0 col1" >46.191898</td>
#       <td id="T_c3772_row0_col2" class="data row0 col2" >7035.378820</td>
#     </tr>
#     <tr>
#       <th id="T_c3772_level0_row1" class="row_heading level0 row1" >min</th>
#       <td id="T_c3772_row1_col0" class="data row1 col0" >0.100000</td>
#       <td id="T_c3772_row1_col1" class="data row1 col1" >30.000000</td>
#       <td id="T_c3772_row1_col2" class="data row1 col2" >4002.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c3772_level0_row2" class="row_heading level0 row2" >25%</th>
#       <td id="T_c3772_row2_col0" class="data row2 col0" >1.000000</td>
#       <td id="T_c3772_row2_col1" class="data row2 col1" >38.000000</td>
#       <td id="T_c3772_row2_col2" class="data row2 col2" >5631.500000</td>
#     </tr>
#     <tr>
#       <th id="T_c3772_level0_row3" class="row_heading level0 row3" >50%</th>
#       <td id="T_c3772_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_c3772_row3_col1" class="data row3 col1" >46.000000</td>
#       <td id="T_c3772_row3_col2" class="data row3 col2" >6612.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c3772_level0_row4" class="row_heading level0 row4" >75%</th>
#       <td id="T_c3772_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_c3772_row4_col1" class="data row4 col1" >54.000000</td>
#       <td id="T_c3772_row4_col2" class="data row4 col2" >7583.500000</td>
#     </tr>
#     <tr>
#       <th id="T_c3772_level0_row5" class="row_heading level0 row5" >max</th>
#       <td id="T_c3772_row5_col0" class="data row5 col0" >1.000000</td>
#       <td id="T_c3772_row5_col1" class="data row5 col1" >62.000000</td>
#       <td id="T_c3772_row5_col2" class="data row5 col2" >14850.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Ścieżka do obrazu
#image_path = r"C:\Users\Grzegorz\Documents\GitHub\HRDataViz\graphics\bow.png"

# Tworzenie pliku PDF
c = canvas.Canvas(destination_path, pagesize=letter)
c.setFont('Helvetica-Bold', 20)  # Ustawienie używanego fontu

# Dodanie tekstu
c.drawString(235, 735, "HR - employee stats")

# Dodanie obrazu
img = utils.ImageReader(image_path)
c.drawImage(img, 205, 730, 25, 25)

# Zapisanie pliku PDF
c.save()
